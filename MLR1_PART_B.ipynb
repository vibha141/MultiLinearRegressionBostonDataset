# %% [markdown]
# <a href="https://colab.research.google.com/github/vibha141/MultiLinearRegressionBostonDataset/blob/main/MLR1_PART_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/boston.csv')
df
# Out:
#         CRIM  INDUS    NOX     RM        AGE     DIS  TAX         PT  \
# 0    0.00632   2.31  0.538  6.575  65.199997  4.0900  296  15.300000
# 1    0.02731   7.07  0.469  6.421  78.900002  4.9671  242  17.799999
# 2    0.02729   7.07  0.469  7.185  61.099998  4.9671  242  17.799999
# 3    0.03237   2.18  0.458  6.998  45.799999  6.0622  222  18.700001
# 4    0.06905   2.18  0.458  7.147  54.200001  6.0622  222  18.700001
# ..       ...    ...    ...    ...        ...     ...  ...        ...
# 501  0.06263  11.93  0.573  6.593  69.099998  2.4786  273  21.000000
# 502  0.04527  11.93  0.573  6.120  76.699997  2.2875  273  21.000000
# 503  0.06076  11.93  0.573  6.976  91.000000  2.1675  273  21.000000
# 504  0.10959  11.93  0.573  6.794  89.300003  2.3889  273  21.000000
# 505  0.04741  11.93  0.573  6.030  80.800003  2.5050  273  21.000000
#
#               B         MV
# 0    396.899994  24.000000
# 1    396.899994  21.600000
# 2    392.829987  34.700001
# ...

# %%
y = df['MV']
x = df

# %%
x
# Out:
#         CRIM  INDUS    NOX     RM        AGE     DIS  TAX         PT  \
# 0    0.00632   2.31  0.538  6.575  65.199997  4.0900  296  15.300000
# 1    0.02731   7.07  0.469  6.421  78.900002  4.9671  242  17.799999
# 2    0.02729   7.07  0.469  7.185  61.099998  4.9671  242  17.799999
# 3    0.03237   2.18  0.458  6.998  45.799999  6.0622  222  18.700001
# 4    0.06905   2.18  0.458  7.147  54.200001  6.0622  222  18.700001
# ..       ...    ...    ...    ...        ...     ...  ...        ...
# 501  0.06263  11.93  0.573  6.593  69.099998  2.4786  273  21.000000
# 502  0.04527  11.93  0.573  6.120  76.699997  2.2875  273  21.000000
# 503  0.06076  11.93  0.573  6.976  91.000000  2.1675  273  21.000000
# 504  0.10959  11.93  0.573  6.794  89.300003  2.3889  273  21.000000
# 505  0.04741  11.93  0.573  6.030  80.800003  2.5050  273  21.000000
#
#               B         MV
# 0    396.899994  24.000000
# 1    396.899994  21.600000
# 2    392.829987  34.700001
# ...

# %%
y
# Out:
# 0      24.000000
# 1      21.600000
# 2      34.700001
# 3      33.400002
# 4      36.200001
#          ...
# 501    22.400000
# 502    20.600000
# 503    23.900000
# 504    22.000000
# 505    11.900000
# Name: MV, Length: 506, dtype: float64

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
corr = df.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4eb52_row0_col0, #T_4eb52_row1_col1, #T_4eb52_row2_col2, #T_4eb52_row3_col3, #T_4eb52_row4_col4, #T_4eb52_row5_col5, #T_4eb52_row6_col6, #T_4eb52_row7_col7, #T_4eb52_row8_col8, #T_4eb52_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4eb52_row0_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_4eb52_row0_col2 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_4eb52_row0_col3, #T_4eb52_row3_col0 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_4eb52_row0_col4 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_4eb52_row0_col5, #T_4eb52_row8_col2, #T_4eb52_row8_col7 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_4eb52_row0_col6 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_4eb52_row0_col7 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_4eb52_row0_col8, #T_4eb52_row2_col8, #T_4eb52_row9_col6 {
#   background-color: #465ecf;
# ...

# %%
import seaborn as sns

sns.heatmap(df.corr())

# %%
df.shape
# Out:
# (506, 10)

# %%
df.isnull().sum()
# Out:
# CRIM     0
# INDUS    0
# NOX      0
# RM       0
# AGE      0
# DIS      0
# TAX      0
# PT       0
# B        0
# MV       0
# dtype: int64

# %% [markdown]
# **PREDICTION OF THE MODEL BASED ON EVERY SIGNIFICANT** **PREDICTOR**

# %%
x = df.drop(["DIS"],axis=1,inplace =True)

# %%
df
# Out:
#         CRIM  INDUS    NOX     RM        AGE  TAX         PT           B  \
# 0    0.00632   2.31  0.538  6.575  65.199997  296  15.300000  396.899994
# 1    0.02731   7.07  0.469  6.421  78.900002  242  17.799999  396.899994
# 2    0.02729   7.07  0.469  7.185  61.099998  242  17.799999  392.829987
# 3    0.03237   2.18  0.458  6.998  45.799999  222  18.700001  394.630005
# 4    0.06905   2.18  0.458  7.147  54.200001  222  18.700001  396.899994
# ..       ...    ...    ...    ...        ...  ...        ...         ...
# 501  0.06263  11.93  0.573  6.593  69.099998  273  21.000000  391.989990
# 502  0.04527  11.93  0.573  6.120  76.699997  273  21.000000  396.899994
# 503  0.06076  11.93  0.573  6.976  91.000000  273  21.000000  396.899994
# 504  0.10959  11.93  0.573  6.794  89.300003  273  21.000000  393.450012
# 505  0.04741  11.93  0.573  6.030  80.800003  273  21.000000  396.899994
#
#             MV
# 0    24.000000
# 1    21.600000
# 2    34.700001
# 3    33.400002
# ...

# %%
df.drop(['B'],axis=1,inplace =True)

# %%
y = df.pop('MV')
x = df

# %%
x
# Out:
#         CRIM  INDUS    NOX     RM        AGE  TAX         PT
# 0    0.00632   2.31  0.538  6.575  65.199997  296  15.300000
# 1    0.02731   7.07  0.469  6.421  78.900002  242  17.799999
# 2    0.02729   7.07  0.469  7.185  61.099998  242  17.799999
# 3    0.03237   2.18  0.458  6.998  45.799999  222  18.700001
# 4    0.06905   2.18  0.458  7.147  54.200001  222  18.700001
# ..       ...    ...    ...    ...        ...  ...        ...
# 501  0.06263  11.93  0.573  6.593  69.099998  273  21.000000
# 502  0.04527  11.93  0.573  6.120  76.699997  273  21.000000
# 503  0.06076  11.93  0.573  6.976  91.000000  273  21.000000
# 504  0.10959  11.93  0.573  6.794  89.300003  273  21.000000
# 505  0.04741  11.93  0.573  6.030  80.800003  273  21.000000
#
# [506 rows x 7 columns]

# %%
y
# Out:
# 0      24.000000
# 1      21.600000
# 2      34.700001
# 3      33.400002
# 4      36.200001
#          ...
# 501    22.400000
# 502    20.600000
# 503    23.900000
# 504    22.000000
# 505    11.900000
# Name: MV, Length: 506, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
LR = LinearRegression()
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_prediction =  LR.predict(x_test)
y_prediction
# Out:
# array([25.64172265, 29.0314481 , 18.86475207, 23.53873302, 18.68396102,
#        24.04442333, 20.37409415, 19.21979723, 20.22760605, 19.85900438,
#        22.7435629 , 24.11862327,  0.09791582, 24.09663507, 18.24854601,
#        25.14447533, 20.42156336,  7.11811075, 39.98090308, 17.14239695,
#        24.55518945, 27.05079796, 15.9952233 , 22.99111908, 16.19128794,
#        13.24261794, 21.82525862, 21.1204762 , 21.05173266, 18.33940691,
#        19.46165509, 23.85479534, 24.26313929, 11.46853742, 17.93572722,
#        19.14811363, 31.25661308, 19.1158761 , 22.4187379 , 24.85274118,
#        15.37779205, 27.68574407, 41.15225125, 19.44675692, 25.04685757,
#        14.23898141, 15.88896622, 26.1021069 , 19.3654981 , 27.97905736,
#        24.21774909, 32.95929503, 19.12158492, 24.41640302, 36.65265066,
#        21.07179739, 17.60884999, 28.58988374, 25.05337228, 18.49564625,
#        26.58618525, 32.58074034, 27.173711  , 15.25143797, 26.63244705,
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
score=r2_score(y_test,y_prediction)
print('r2 score is ',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,y_prediction))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2 score is  0.6220142571515084
# mean_sqrd_error is== 28.164888452757292
# root_mean_squared error of is== 5.307060245819459

# %%
from sklearn.metrics import mean_squared_error 
mse = mean_squared_error(y_test, y_prediction) 
print("Mean Square Error : ", mse)
# Out:
# Mean Square Error :  28.164888452757292

# %%
df1 = pd.DataFrame({'Actual': y_test, 'Predicted':y_prediction})
df1
# Out:
#         Actual  Predicted
# 173  23.600000  25.641723
# 274  32.400002  29.031448
# 491  13.600000  18.864752
# 72   22.799999  23.538733
# 452  16.100000  18.683961
# ..         ...        ...
# 441  17.100000  18.430840
# 23   14.500000  16.628136
# 225  50.000000  41.705694
# 433  14.300000  19.689315
# 447  12.600000  17.294517
#
# [152 rows x 2 columns]

# %%
plt.scatter(y_test, y_prediction, c = 'blue')

# %% [markdown]
# **PREDICTION OF MODEL BASED ON 2 STRONG** **PREDICTORS**

# %%
x1=df["RM"]

# %%
x1
# Out:
# 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 501    6.593
# 502    6.120
# 503    6.976
# 504    6.794
# 505    6.030
# Name: RM, Length: 506, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x1, y, test_size = 0.3, random_state = 42)

# %%
LR = LinearRegression()
LR.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_prediction =  LR.predict(x_test.values.reshape(-1,1))
y_prediction
# Out:
# array([23.8394352 , 26.95782614, 19.89129627, 20.63898295, 22.75438146,
#        22.59025447, 19.26214935, 21.6328536 , 22.13435199, 20.29249411,
#        19.59952077, 20.08277992,  6.54239732, 22.16170431, 17.38382171,
#        28.98204588, 18.94301718,  9.83403268, 37.14274695, 21.73315415,
#        22.23464819, 24.4412298 , 17.42940892, 25.45333967, 20.1010148 ,
#        14.82163382, 18.89742562, 26.68428552, 19.68158208, 18.16797817,
#        16.14375842, 23.93061831, 32.0183755 , 14.22895667, 20.07365814,
#        17.39293916, 30.85125609, 18.85183407, 20.62986552, 22.28023975,
#        14.4842624 , 27.78757415, 38.59252878, 16.34435517, 23.84855265,
#        17.42940892, 17.31999528, 23.84855265, 21.56902716, 25.28921268,
#        20.12836713, 28.87262789, 21.34107809, 27.16754467, 33.44991375,
#        22.89115177, 22.04316888, 27.89699214, 23.59324691, 16.44465572,
#        26.99430025, 31.43481579, 25.0794985 , 15.08605699, 25.3256868 ,
# ...

# %%
print('r2 score is ',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,y_prediction))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2 score is  0.6220142571515084
# mean_sqrd_error is== 40.35144988137381
# root_mean_squared error of is== 6.352279109215354

# %%
mse = mean_squared_error(y_test, y_prediction) 
print("Mean Square Error : ", mse)
# Out:
# Mean Square Error :  40.35144988137381

# %%
df2 = pd.DataFrame({'Actual': y_test, 'Predicted':y_prediction})
df2
# Out:
#         Actual  Predicted
# 173  23.600000  23.839435
# 274  32.400002  26.957826
# 491  13.600000  19.891296
# 72   22.799999  20.638983
# 452  16.100000  22.754381
# ..         ...        ...
# 441  17.100000  23.748256
# 23   14.500000  18.341223
# 225  50.000000  44.893137
# 433  14.300000  24.021797
# 447  12.600000  22.334949
#
# [152 rows x 2 columns]

# %%
plt.scatter(y_test, y_prediction, c = 'green')

# %% [markdown]
# **PREDICTION USING ONE STRONG PREDICTOR**

# %%
x2=df['RM']

# %%
x2
# Out:
# 0      6.575
# 1      6.421
# 2      7.185
# 3      6.998
# 4      7.147
#        ...
# 501    6.593
# 502    6.120
# 503    6.976
# 504    6.794
# 505    6.030
# Name: RM, Length: 506, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x2, y, test_size = 0.3, random_state = 42)

# %%
LR = LinearRegression()
LR.fit(x_train.values.reshape(-1,1),y_train)
# Out:
# LinearRegression()

# %%
y_prediction =  LR.predict(x_test.values.reshape(-1,1))
y_prediction
# Out:
# array([23.8394352 , 26.95782614, 19.89129627, 20.63898295, 22.75438146,
#        22.59025447, 19.26214935, 21.6328536 , 22.13435199, 20.29249411,
#        19.59952077, 20.08277992,  6.54239732, 22.16170431, 17.38382171,
#        28.98204588, 18.94301718,  9.83403268, 37.14274695, 21.73315415,
#        22.23464819, 24.4412298 , 17.42940892, 25.45333967, 20.1010148 ,
#        14.82163382, 18.89742562, 26.68428552, 19.68158208, 18.16797817,
#        16.14375842, 23.93061831, 32.0183755 , 14.22895667, 20.07365814,
#        17.39293916, 30.85125609, 18.85183407, 20.62986552, 22.28023975,
#        14.4842624 , 27.78757415, 38.59252878, 16.34435517, 23.84855265,
#        17.42940892, 17.31999528, 23.84855265, 21.56902716, 25.28921268,
#        20.12836713, 28.87262789, 21.34107809, 27.16754467, 33.44991375,
#        22.89115177, 22.04316888, 27.89699214, 23.59324691, 16.44465572,
#        26.99430025, 31.43481579, 25.0794985 , 15.08605699, 25.3256868 ,
# ...

# %%
print('r2 score is ',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,y_prediction))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_prediction)))
# Out:
# r2 score is  0.6220142571515084
# mean_sqrd_error is== 40.35144988137381
# root_mean_squared error of is== 6.352279109215354

# %%
df3 = pd.DataFrame({'Actual': y_test, 'Predicted':y_prediction})
df3
# Out:
#         Actual  Predicted
# 173  23.600000  23.839435
# 274  32.400002  26.957826
# 491  13.600000  19.891296
# 72   22.799999  20.638983
# 452  16.100000  22.754381
# ..         ...        ...
# 441  17.100000  23.748256
# 23   14.500000  18.341223
# 225  50.000000  44.893137
# 433  14.300000  24.021797
# 447  12.600000  22.334949
#
# [152 rows x 2 columns]

# %%
plt.scatter(y_test, y_prediction, c = 'red')
